# %% [markdown]
# # Quickstart
#
# 这是一个用于测试网页 Notebook 阅读的示例。
#
# <img src="../assets/learning-map.svg" width="400">

# %%
items = [1, 2, 3]
sum(items)
# Out:
# items = [1, 2, 3]
# sum(items) = 6

# %%
sum(items)
# Out:
# 6
